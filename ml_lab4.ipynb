# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import mutual_info_classif

 

# creation of dataframe
df= pd.DataFrame({
    'age': ['<=30', '<=30', '31-40', '>40', '>40', '>40', '31-40', '<=30', '<=30', '>40', '<=30', '31-40', '31-40', '>40'],
    'income': ['high', 'high', 'high', 'medium', 'low', 'low', 'low', 'medium', 'low', 'medium', 'medium', 'medium', 'high', 'medium'],
    'student': ['no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'no'],
    'credit_rating': ['fair', 'excellent', 'fair', 'fair', 'fair', 'excellent', 'excellent', 'fair', 'fair', 'fair', 'excellent', 'excellent', 'fair', 'excellent'],
    'buys_computer': ['no', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
})
df
# Out:
#       age  income student credit_rating buys_computer
# 0    <=30    high      no          fair            no
# 1    <=30    high      no     excellent            no
# 2   31-40    high      no          fair           yes
# 3     >40  medium      no          fair           yes
# 4     >40     low     yes          fair           yes
# 5     >40     low     yes     excellent            no
# 6   31-40     low     yes     excellent           yes
# 7    <=30  medium      no          fair            no
# 8    <=30     low     yes          fair           yes
# 9     >40  medium     yes          fair           yes
# 10   <=30  medium     yes     excellent           yes
# 11  31-40  medium      no     excellent           yes
# 12  31-40    high     yes          fair           yes
# 13    >40  medium      no     excellent            no

# %%
# entropy for the 'buys_computer' attribute
def calculate_entropy(data, target_attribute):
    total_samples = len(data)
    class_labels = data[target_attribute].value_counts()
    entropy = 0
    for label in class_labels:
        proportion = label / total_samples
        entropy -= proportion * math.log2(proportion)
    return entropy

# entropy for 'buys_computer'
entropy_buys_computer = calculate_entropy(df, 'buys_computer')
print("Entropy for 'buys_computer':", entropy_buys_computer)

# entropy for each feature and information gain
def calculate_information_gain(data, target_attribute, feature):
    entropy = calculate_entropy(data, target_attribute)
    unique_values = data[feature].unique()
    weighted_entropy = 0
    for value in unique_values:
        subset = data[data[feature] == value]
        subset_entropy = calculate_entropy(subset, target_attribute)
        weight = len(subset) / len(data)
        weighted_entropy += weight * subset_entropy
    information_gain = entropy - weighted_entropy
    return information_gain

# information gain for each feature
information_gains = {}
for feature in df.columns[:-1]:  # Exclude the last column (class label)
    information_gain = calculate_information_gain(df, 'buys_computer', feature)
    information_gains[feature] = information_gain

# Print information 
print("\nInformation Gains:")
for feature, gain in information_gains.items():
    print(f"{feature}: {gain}")
# Out:
# Entropy for 'buys_computer': 0.9402859586706311
#
# Information Gains:
# age: 0.24674981977443933
# income: 0.02922256565895487
# student: 0.15183550136234159
# credit_rating: 0.04812703040826949

# %%
# Identify the  highest feature information gain root node
root_node = max(information_gains, key=information_gains.get)
print("\nThe first feature for constructing the decision tree (root node):", root_node)
# Out:
# The first feature for constructing the decision tree (root node): age
